# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
imagem = cv2.imread('mm.jpg')
cv2_imshow(imagem)
# Out:
# <PIL.Image.Image image mode=RGB size=600x400>

# %%
print('altura de pixels', imagem.shape[0])
# Out:
# quantidade de pixels 400

# %%
print('largura em pixels', imagem.shape[1])
# Out:
# largura em pixels 600

# %%
print('quantidade de canais', imagem.shape[2])
# Out:
# quantidade de canais 3

# %%
imagem
# Out:
# array([[[245, 246, 248],
#         [245, 246, 248],
#         [245, 246, 248],
#         ...,
#         [247, 246, 248],
#         [247, 246, 248],
#         [247, 246, 248]],
#
#        [[245, 246, 248],
#         [245, 246, 248],
#         [245, 246, 248],
#         ...,
#         [247, 246, 248],
#         [247, 246, 248],
#         [247, 246, 248]],
#
#        [[245, 246, 248],
#         [245, 246, 248],
#         [245, 246, 248],
#         ...,
#         [248, 247, 250],
#         [248, 247, 250],
#         [248, 247, 250]],
#
#        ...,
#
#        [[247, 247, 247],
#         [247, 247, 247],
#         [247, 247, 247],
#         ...,
#         [250, 248, 248],
#         [250, 248, 248],
#         [250, 248, 248]],
#
#        [[247, 247, 247],
#         [247, 247, 247],
#         [247, 247, 247],
#         ...,
#         [250, 248, 248],
#         [250, 248, 248],
#         [250, 248, 248]],
#
#        [[247, 247, 247],
#         [247, 247, 247],
#         [247, 247, 247],
#         ...,
#         [250, 248, 248],
#         [250, 248, 248],
#         [250, 248, 248]]], dtype=uint8)
